# %%
#INSTALAR LIBRERIAS
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install openpyxl
# !pip3 install sympy
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=2.3.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 20.1 MB/s  0:00:00eta 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.5.2)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.25 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 18.8 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pyparsing-3.3.2
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/juanpablosolis/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 19.1 MB/s  0:00:00 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 13.4 MB/s  0:00:00
# Installing collected packages: mpmath, sympy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sympy]32m1/2 [sympy]
# Successfully installed mpmath-1.3.0 sympy-1.14.0

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sympy import primerange
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("los-angeles.csv")
df
# Out:
#                         id                                               name  \
# 0                     2708  Run Runyon, Beaut Furn Mirror Mini-Suit w/ Fir...
# 1                     2732                              Zen Life at the Beach
# 2                     6033                           Poolside Serenity Studio
# 3                     6931  RUN Runyon, Beau Furn Rms Terrace Hollyw Hill ...
# 4                     7874      HD Wi-Fi E Bellflower Cerritos Lakewood LB LA
# ...                    ...                                                ...
# 43927  1707678777570851520  The French Lime Pool House - Sleeps 8 - Air ho...
# 43928  1707701464310658544                   Hollywood City Views The Godfrey
# 43929  1707712658970417218             Spacious Waterfront 3BR Marina Retreat
# 43930  1707714248958928308                      Zen in Hollywood Walk of Fame
# 43931  1707753561170835767                                   West Hills Oasis
#
#            host_id  host_profile_id      host_name   neighbourhood_group  \
# 0           3008.0     1.462506e+18        ⁨Chas.⁩   City of Los Angeles
# 1           3041.0     1.462506e+18  Yogapriestess          Other Cities
# 2          11619.0     1.462507e+18          Sarah   City of Los Angeles
# 3           3008.0     1.462506e+18        ⁨Chas.⁩   City of Los Angeles
# 4          21700.0     1.462507e+18          Henry          Other Cities
# ...            ...              ...            ...                   ...
# 43927  588675098.0     1.463893e+18           Posh  Unincorporated Areas
# 43928  383724181.0     1.469787e+18     Upscale LA          Other Cities
# 43929  412269286.0     1.469879e+18            Tee  Unincorporated Areas
# 43930  383724181.0     1.469787e+18     Upscale LA          Other Cities
# 43931  382786700.0     1.469784e+18          Azita          Other Cities
#
#                neighbourhood   latitude   longitude        room_type  price  \
# 0                  Hollywood  34.096250 -118.346050     Private room   67.0
# 1               Santa Monica  34.004400 -118.480950     Private room  214.0
# 2             Woodland Hills  34.168870 -118.644780  Entire home/apt  100.0
# 3                  Hollywood  34.096260 -118.343720     Private room   95.0
# 4                 Bellflower  33.876870 -118.114440     Private room  113.0
# ...                      ...        ...         ...              ...    ...
# 43927  Desert View Highlands  34.587350 -118.160880  Entire home/apt  220.0
# 43928         West Hollywood  34.093596 -118.343729  Entire home/apt  399.0
# 43929         Marina del Rey  33.976153 -118.452329  Entire home/apt  927.0
# 43930         West Hollywood  34.093596 -118.343729  Entire home/apt  532.0
# 43931              Calabasas  34.140982 -118.653587  Entire home/apt  296.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                30.0                 47  2026-05-26               0.32
# 1                 1.0                 24  2022-08-21               0.13
# 2                30.0                 19  2020-03-22               0.09
# 3                30.0                 39  2025-12-15               0.19
# 4                 1.0                 26  2026-04-02               0.29
# ...               ...                ...         ...                ...
# 43927             2.0                  0         NaN                NaN
# 43928             3.0                  0         NaN                NaN
# 43929            14.0                  0         NaN                NaN
# 43930             1.0                  0         NaN                NaN
# 43931             1.0                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                 2.0               301
# 1                                 2.0               350
# 2                                 7.0               270
# 3                                 2.0               259
# 4                                 4.0               103
# ...                               ...               ...
# 43927                            13.0               361
# 43928                            14.0               361
# 43929                             1.0               365
# 43930                            14.0               361
# 43931                             3.0               363
#
#        number_of_reviews_ltm license
# 0                          3     NaN
# 1                          0  228269
# 2                          0     NaN
# 3                          2     NaN
# 4                          9     NaN
# ...                      ...     ...
# 43927                      0     NaN
# 43928                      0  Exempt
# 43929                      0     NaN
# 43930                      0  Exempt
# 43931                      0     NaN
#
# [43932 rows x 19 columns]

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43932 entries, 0 to 43931
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              43932 non-null  int64
#  1   name                            43932 non-null  str
#  2   host_id                         43751 non-null  float64
#  3   host_profile_id                 43537 non-null  float64
#  4   host_name                       43548 non-null  str
#  5   neighbourhood_group             43932 non-null  str
#  6   neighbourhood                   43932 non-null  str
#  7   latitude                        43932 non-null  float64
#  8   longitude                       43932 non-null  float64
#  9   room_type                       43932 non-null  str
#  10  price                           38362 non-null  float64
#  11  minimum_nights                  43921 non-null  float64
#  12  number_of_reviews               43932 non-null  int64
#  13  last_review                     32621 non-null  str
#  14  reviews_per_month               32621 non-null  float64
#  15  calculated_host_listings_count  43751 non-null  float64
#  16  availability_365                43932 non-null  int64
#  17  number_of_reviews_ltm           43932 non-null  int64
#  18  license                         13192 non-null  str
# dtypes: float64(8), int64(4), str(7)
# memory usage: 6.4 MB

# %%
#Convertimos el DataFrame de pandas en un arreglo de numpy
array = df.to_numpy()
array
# Out:
# array([[28871, 'Comfortable double room', 124245.0, ..., 11, 88,
#         '0363 607B EA74 0BD8 2F6F'],
#        [29051, 'Comfortable single / double room', 124245.0, ..., 2, 82,
#         '0363 607B EA74 0BD8 2F6F'],
#        [44129, 'Luxury design with canal view', 187728.0, ..., 3, 5,
#         '03635399E87602900F47'],
#        ...,
#        [1708105472694968020,
#         'Two bedroom apt in the best location of Amsterdam',
#         1.705253369814659e+18, ..., 19, 0, '0363 8C4D 1A2F 4D51 9B6C'],
#        [1708115205290482378,
#         'Single Bedroom apt in the heart of Amsterdam',
#         1.705253369814659e+18, ..., 35, 0, '036302DC0A50A5E48A8A'],
#        [1708158632781004601, 'The Grand canal residence', 753265755.0,
#         ..., 353, 0, 'AMBN 4821 nk7p 54xd b3f8']],
#       shape=(10465, 19), dtype=object)

# %% [markdown]
# ***Indexación de un array 1D a partir de un array 2D***

# %%
# Acceder a la primera fila de un arreglo de numpy
fila0 = array[0]
fila0
# Out:
# array([28871, 'Comfortable double room', 124245.0, 1.462510208428039e+18,
#        'Edwin', nan, 'Centrum-West', 52.36775, 4.89092, 'Private room',
#        94.0, 1.0, 799, '2026-06-01', 4.15, 2.0, 11, 88,
#        '0363 607B EA74 0BD8 2F6F'], dtype=object)

# %%
# Acceder a la primera fila de un Dataframe de pandas
fila0 = df.iloc[0]
fila0
# Out:
# id                                                   28871
# name                               Comfortable double room
# host_id                                           124245.0
# host_profile_id                      1462510208428038912.0
# host_name                                            Edwin
# neighbourhood_group                                    NaN
# neighbourhood                                 Centrum-West
# latitude                                          52.36775
# longitude                                          4.89092
# room_type                                     Private room
# price                                                 94.0
# minimum_nights                                         1.0
# number_of_reviews                                      799
# last_review                                     2026-06-01
# reviews_per_month                                     4.15
# calculated_host_listings_count                         2.0
# availability_365                                        11
# number_of_reviews_ltm                                   88
# license                           0363 607B EA74 0BD8 2F6F
# Name: 0, dtype: object

# %%
# Acceder a la primera fila de un arreglo de numpy
columna0 = array[:, 0]
columna0
# Out:
# array([28871, 29051, 44129, ..., 1708105472694968020, 1708115205290482378,
#        1708158632781004601], shape=(10465,), dtype=object)

# %% [markdown]
# ***Indexación de múltiples arrays 1D a partir de un array 2D***

# %%
#Filas consecutivas 3-5 y la columna 4
Filas_3_a_5= array[3:6, 4]       
Filas_3_a_5
# Out:
# array(['Jan', 'Vesna & Misha', 'Joanna & MP'], dtype=object)

# %%
#Filas no consecutivas 2, 8, 12 y Todas las columnas
Filas_3_a_5= array[[2, 8, 12], :]       
Filas_3_a_5
# Out:
# array([[44129, 'Luxury design with canal view', 187728.0,
#         1.4625121252931446e+18, 'Tanya', nan, 'Centrum-West', 52.38211,
#         4.8863, 'Entire home/apt', 314.0, 3.0, 186, '2026-04-30', 0.96,
#         4.0, 3, 5, '03635399E87602900F47'],
#        [53921, 'Amsterdam Stylish Lakeview Apartment', 252245.0,
#         1.4625138100020278e+18, 'Ingrid', nan,
#         'IJburg - Zeeburgereiland', 52.35559, 5.0032, 'Entire home/apt',
#         nan, 1.0, 12, '2024-05-25', 0.13, 1.0, 0, 0,
#         '0363 B43C B1D4 2666 3739'],
#        [91535, 'Privat room and shared Houseboat "Ramona" centre',
#         494281.0, 1.4625198492251617e+18, 'Michiel', nan,
#         'De Pijp - Rivierenbuurt', 52.35774, 4.89647, 'Private room',
#         269.0, 1.0, 334, '2026-06-13', 1.84, 1.0, 42, 37,
#         '0363 74BA 2074 E0CF 1CB8']], dtype=object)

# %%
#Filas combinadas 0, 4-6 y 10 y columna 4
Filas_0_4_5_6_10= array[[0] + list(range(4, 7)) + [10], 4]       
Filas_0_4_5_6_10
# Out:
# array(['Edwin', 'Vesna & Misha', 'Joanna & MP', 'Donald', 'Jessica'],
#       dtype=object)

# %%
#Filas pares y todas las columnas
Filas_pares = array[::2, :]
Filas_pares
# Out:
# array([[28871, 'Comfortable double room', 124245.0, ..., 11, 88,
#         '0363 607B EA74 0BD8 2F6F'],
#        [44129, 'Luxury design with canal view', 187728.0, ..., 3, 5,
#         '03635399E87602900F47'],
#        [48373, 'Cozy family home in Amsterdam South', 220434.0, ..., 0,
#         0, '0363 4A2B A6AD 0196 F684'],
#        ...,
#        [1708031597364214682,
#         'Lovely room with balcony in the heart of Amsterdam',
#         1.705253369814659e+18, ..., 34, 0, '0363 8C4D 1A2F 4D51 9B6C'],
#        [1708105472694968020,
#         'Two bedroom apt in the best location of Amsterdam',
#         1.705253369814659e+18, ..., 19, 0, '0363 8C4D 1A2F 4D51 9B6C'],
#        [1708158632781004601, 'The Grand canal residence', 753265755.0,
#         ..., 353, 0, 'AMBN 4821 nk7p 54xd b3f8']],
#       shape=(5233, 19), dtype=object)

# %%
#Filas impares y todas las columnas
Filas_impares = array[1::2, :]
Filas_impares
# Out:
# array([[29051, 'Comfortable single / double room', 124245.0, ..., 2, 82,
#         '0363 607B EA74 0BD8 2F6F'],
#        [44391, 'Quiet 2-bedroom Amsterdam city centre apartment',
#         194779.0, ..., 0, 0, '0363 E76E F06A C1DD 172C'],
#        [49552, 'Multatuli Luxury Guest Suite in top location', 225987.0,
#         ..., 278, 57, '0363 576A D827 5085 6B83'],
#        ...,
#        [1708005776145639009, 'Dam Center Oasis', 481069764.0, ..., 37, 0,
#         '0363 834B F21D CE73 4AD8'],
#        [1708094794334709654, 'Keizers Canal Home', 481069764.0, ..., 43,
#         0, '0363 31C4 7BD8 1F63 4A61'],
#        [1708115205290482378,
#         'Single Bedroom apt in the heart of Amsterdam',
#         1.705253369814659e+18, ..., 35, 0, '036302DC0A50A5E48A8A']],
#       shape=(5232, 19), dtype=object)

# %%
#Filas primas y todas las columnas
primos = list(primerange(0, 20))
Filas_primas = array[primos, :]
Filas_primas
# Out:
# array([[44129, 'Luxury design with canal view', 187728.0,
#         1.4625121252931446e+18, 'Tanya', nan, 'Centrum-West', 52.38211,
#         4.8863, 'Entire home/apt', 314.0, 3.0, 186, '2026-04-30', 0.96,
#         4.0, 3, 5, '03635399E87602900F47'],
#        [44391, 'Quiet 2-bedroom Amsterdam city centre apartment',
#         194779.0, 1.4625123369036503e+18, 'Jan', nan, 'Centrum-Oost',
#         52.37168, 4.91471, 'Entire home/apt', nan, 3.0, 42, '2022-08-20',
#         0.22, 1.0, 0, 0, '0363 E76E F06A C1DD 172C'],
#        [49552, 'Multatuli Luxury Guest Suite in top location', 225987.0,
#         1.4625131522578511e+18, 'Joanna & MP', nan, 'Centrum-West',
#         52.38028, 4.89089, 'Entire home/apt', 440.0, 2.0, 656,
#         '2026-06-07', 3.45, 1.0, 278, 57, '0363 576A D827 5085 6B83'],
#        [50523, 'B & B de 9 Straatjes (city center)', 231946.0,
#         1.4625133203240108e+18, 'Raymond', nan, 'Centrum-West', 52.36959,
#         4.88423, 'Entire home/apt', 154.0, 1.0, 631, '2026-05-31', 3.35,
#         1.0, 242, 86, '0363 22DC 0E52 B70B 0FB8'],
#        [80635, 'TOP LOCATED Canalhouse B&B Jordaan', 436145.0,
#         1.462511822906232e+18, 'Riks', nan, 'Centrum-West', 52.37828,
#         4.8944, 'Private room', nan, 3.0, 241, '2022-12-31', 1.3, 4.0, 0,
#         0, '0363 4108 6EC3 C2FF 2493'],
#        [97221, 'Beautiful and spacious room', 195859.0,
#         1.4625123587060265e+18, 'Giovanni Salvatore Maria', nan,
#         'Slotervaart', 52.34801, 4.83639, 'Private room', 86.0, 2.0, 447,
#         '2026-05-24', 2.46, 2.0, 278, 40, '0363 BCBA 6311 3268 DC8C'],
#        [168769, 'SUPERLOCATED Room in  CANALHOUSE, Private bath',
#         436145.0, 1.462511822906232e+18, 'Riks', nan, 'Centrum-West',
#         52.37956, 4.89359, 'Private room', nan, 3.0, 278, '2022-12-29',
#         1.55, 4.0, 0, 0, '0363 4108 6EC3 C2FF 2493'],
#        [179528, 'Authentic Amsterdam Apartment RAI', 856540.0,
#         1.4625314355052547e+18, 'Pierre', nan, 'De Pijp - Rivierenbuurt',
#         52.34332, 4.89484, 'Entire home/apt', 462.0, 6.0, 40,
#         '2025-10-24', 0.22, 2.0, 258, 4, '0363 1C26 67B4 C610 1758']],
#       dtype=object)

# %%
#Convertir un arreglo de numpy a CSV
np.savetxt("datos_numpy.csv", array, delimiter=",", fmt="%s", encoding="utf-8")

# %%
#Convertir un dataframe de pandas a CSV
df.to_csv("datos_pandas.csv")
